# %% [markdown]
# ## 2) Inferential analysis (matched cohort): baseline + exposures

# %%
import pandas as pd
import numpy as np
from pathlib import Path

project_root = Path.cwd().parent
data_path = project_root / "data" / "raw" / "HO_infxn_analysis.csv"
df = pd.read_csv(data_path)

df.shape
# Out:
# (120279, 78)

# %%
import statsmodels.api as sm

# Build feature list
baseline_cols = []
for c in ["age", "sex"]:
    if c in df.columns:
        baseline_cols.append(c)
baseline_cols += [c for c in df.columns if c.startswith("elix_")]

# Drop outcome missing rows (should be none)
d = df.dropna(subset=["group_binary"]).copy()

# Prepare X/y
X = d[baseline_cols].copy()

# Convert sex to numeric if needed
if "sex" in X.columns and X["sex"].dtype == "object":
    X["sex"] = X["sex"].str.lower().map({"m": 1, "male": 1, "f": 0, "female": 0})

X = sm.add_constant(X, has_constant="add")
y = d["group_binary"].astype(int)

# %%
X.dtypes[X.dtypes == "object"]
# Out:
# age    object
# dtype: object

# %%
df["age"].head(10)
# Out:
# 0    74.5
# 1    71.1
# 2    60.4
# 3    60.4
# 4    43.4
# 5    43.4
# 6    56.5
# 7    56.5
# 8    63.1
# 9    63.1
# Name: age, dtype: object

# %%
X_clean = X.copy()

# Convert age to numeric
X_clean["age"] = pd.to_numeric(X_clean["age"], errors="coerce")

# Verify no object columns remain
X_clean.dtypes[X_clean.dtypes == "object"]
# Out:
# Series([], dtype: object)

# %%
X2 = sm.add_constant(X_clean, has_constant="add")

# Keep only rows with complete predictors
mask = X2.notna().all(axis=1)
X2 = X2.loc[mask]
y2 = y.loc[mask]

print("Rows before:", len(y), "Rows after:", len(y2))

model_baseline = sm.Logit(y2, X2).fit(disp=False)
model_baseline.summary()
# Out:
# Rows before: 120279 Rows after: 112806
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           group_binary   No. Observations:               112806
# Model:                          Logit   Df Residuals:                   112764
# Method:                           MLE   Df Model:                           41
# Date:                Sat, 14 Feb 2026   Pseudo R-squ.:                0.005595
# Time:                        15:46:20   Log-Likelihood:                -70079.
# converged:                       True   LL-Null:                       -70474.
# Covariance Type:            nonrobust   LLR p-value:                4.556e-139
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.3460    8.1e+06  -4.27e-08      1.000   -1.59e+07    1.59e+07
# ...

# %%
params = model_baseline.params
conf = model_baseline.conf_int()

or_table = pd.DataFrame({
    "OR": np.exp(params),
    "CI_low": np.exp(conf[0]),
    "CI_high": np.exp(conf[1]),
    "p_value": model_baseline.pvalues
}).sort_values("p_value")

or_table.head(10)
# Out:
# C:\Users\Alexander Jimenez\hospital-onset-infection-risk-model\.venv\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                          OR    CI_low   CI_high       p_value
# elix_PERIVASC      1.173341  1.119119  1.230189  3.542495e-11
# elix_DEMENTIA      0.861985  0.818501  0.907779  1.871937e-08
# elix_CANCER_SOLID  1.211763  1.133145  1.295836  1.997779e-08
# elix_OBESE         1.153140  1.096331  1.212894  3.239736e-08
# age                0.997751  0.996934  0.998568  7.103987e-08
# elix_LUNG_CHRONIC  0.927383  0.897355  0.958416  7.152595e-06
# elix_CBVD          1.155197  1.081405  1.234024  1.838206e-05
# elix_CANCER_NSITU  1.893865  1.335997  2.684679  3.344368e-04
# elix_CANCER_LEUK   1.210903  1.074669  1.364407  1.675008e-03
# elix_DIAB_CX       0.945850  0.913347  0.979510  1.806438e-03

# %%
cp_cols = [c for c in df.columns if c.endswith("_cp")]
print("CP cols:", cp_cols)

d = df.dropna(subset=["group_binary"]).copy()
X_cp = d[baseline_cols + cp_cols].copy()

for c in X_cp.columns:
    X_cp[c] = pd.to_numeric(X_cp[c], errors="coerce")

X_cp = sm.add_constant(X_cp, has_constant="add")

mask = X_cp.notna().all(axis=1)
print("Rows total:", len(X_cp))
print("Rows complete-case:", int(mask.sum()))
print("\nMissingness in CP cols (top):")
print(d[cp_cols].isna().mean().sort_values(ascending=False).head(10))
# Out:
# CP cols: ['DS_Entero_cp', 'ESBL_cp', 'CDiff_cp', 'VSE_cp', 'VRE_cp', 'MSSA_cp', 'MRSA_cp', 'DS_PsA_cp', 'DR_PsA_cp']
# Rows total: 120279
# Rows complete-case: 0
#
# Missingness in CP cols (top):
# DS_Entero_cp    0.0
# ESBL_cp         0.0
# CDiff_cp        0.0
# VSE_cp          0.0
# VRE_cp          0.0
# MSSA_cp         0.0
# MRSA_cp         0.0
# DS_PsA_cp       0.0
# DR_PsA_cp       0.0
# dtype: float64

# %%
missing_rates = X_cp.isna().mean().sort_values(ascending=False)
missing_rates.head(15)
# Out:
# sex                     1.000000
# age                     0.062114
# const                   0.000000
# elix_index_mortality    0.000000
# elix_AIDS               0.000000
# elix_LUNG_CHRONIC       0.000000
# elix_DEMENTIA           0.000000
# elix_DEPRESS            0.000000
# elix_DIAB_UNCX          0.000000
# elix_DIAB_CX            0.000000
# elix_HTN_UNCX           0.000000
# elix_THYROID_HYPO       0.000000
# elix_THYROID_OTH        0.000000
# elix_CANCER_LYMPH       0.000000
# elix_CANCER_LEUK        0.000000
# dtype: float64

# %%
baseline_cols_clean = []

# Keep age (acceptable missingness)
baseline_cols_clean.append("age")

# Elixhauser flags ONLY (exclude summary index)
baseline_cols_clean += [
    c for c in df.columns
    if c.startswith("elix_") and c != "elix_index_mortality"
]

len(baseline_cols_clean)
# Out:
# 39

# %%
# Build design matrix
X_cp2 = d[baseline_cols_clean + cp_cols].copy()

# Force numeric
for c in X_cp2.columns:
    X_cp2[c] = pd.to_numeric(X_cp2[c], errors="coerce")

X_cp2 = sm.add_constant(X_cp2, has_constant="add")

mask2 = X_cp2.notna().all(axis=1)
print("Rows complete-case (fixed):", int(mask2.sum()))

X_cp2 = X_cp2.loc[mask2]
y_cp2 = y.loc[mask2]

model_cp = sm.Logit(y_cp2, X_cp2).fit(disp=False)
model_cp.summary()
# Out:
# Rows complete-case (fixed): 112808
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           group_binary   No. Observations:               112808
# Model:                          Logit   Df Residuals:                   112759
# Method:                           MLE   Df Model:                           48
# Date:                Sat, 14 Feb 2026   Pseudo R-squ.:                0.007876
# Time:                        15:46:24   Log-Likelihood:                -69920.
# converged:                       True   LL-Null:                       -70475.
# Covariance Type:            nonrobust   LLR p-value:                4.618e-201
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.6479      0.024    -26.687      0.000      -0.695      -0.600
# ...

# %%
from scipy.stats import chi2

lr_stat = 2 * (model_cp.llf - model_baseline.llf)
df_diff = model_cp.df_model - model_baseline.df_model
p_lr = chi2.sf(lr_stat, df_diff)

lr_stat, df_diff, p_lr
# Out:
# (np.float64(318.4356176123547), 7.0, np.float64(6.963326561308847e-65))

# %%
params_cp = model_cp.params
conf_cp = model_cp.conf_int()

or_cp = pd.DataFrame({
    "OR": np.exp(params_cp),
    "CI_low": np.exp(conf_cp[0]),
    "CI_high": np.exp(conf_cp[1]),
    "p_value": model_cp.pvalues
})

or_cp_cpvars = (
    or_cp
    .loc[cp_cols]
    .sort_values("p_value")
)

or_cp_cpvars
# Out:
#                     OR    CI_low   CI_high       p_value
# DS_Entero_cp  0.988901  0.986663  0.991145  4.720887e-22
# CDiff_cp      0.979412  0.969977  0.988939  2.532329e-05
# VRE_cp        1.021928  1.011606  1.032356  2.819681e-05
# ESBL_cp       0.987930  0.982267  0.993626  3.471782e-05
# MSSA_cp       1.009267  1.003677  1.014888  1.132726e-03
# MRSA_cp       0.990305  0.981623  0.999064  3.012960e-02
# DR_PsA_cp     1.001324  0.989180  1.013616  8.317270e-01
# VSE_cp        1.000486  0.994672  1.006334  8.701612e-01
# DS_PsA_cp     1.000470  0.992000  1.009011  9.138002e-01

# %%
abx_cols = [c for c in df.columns if c.endswith("_0_60")]
# make sure any_abx_0_60 is included (it should be)
if "any_abx_0_60" in df.columns and "any_abx_0_60" not in abx_cols:
    abx_cols = ["any_abx_0_60"] + abx_cols

len(abx_cols), abx_cols[:10]
# Out:
# (15,
#  ['any_abx_0_60',
#   'penicillin_0_60',
#   'extended_spectrum_penicillin_0_60',
#   'anti_staph_beta_lactam_0_60',
#   'cephalosporin_0_60',
#   'extended_spectrum_cephalosporin_0_60',
#   'carbapenem_0_60',
#   'fluoroquinolone_0_60',
#   'sulfonamide_0_60',
#   'glycopeptide_0_60'])

# %%
# Patient subset (antibiotic-focused analysis)
d_pat = df[df["analysis"].str.lower().str.contains("pat")].copy()
d_pat = d_pat.dropna(subset=["group_binary"]).copy()

# Design matrix: baseline + antibiotics
X_abx = d_pat[baseline_cols_clean + abx_cols].copy()
for c in X_abx.columns:
    X_abx[c] = pd.to_numeric(X_abx[c], errors="coerce")

X_abx = sm.add_constant(X_abx, has_constant="add")
mask_abx = X_abx.notna().all(axis=1)

X_abx2 = X_abx.loc[mask_abx]
y_abx2 = d_pat.loc[mask_abx, "group_binary"].astype(int)

print("Patient rows:", len(d_pat), "Complete-case:", len(y_abx2))

model_abx = sm.Logit(y_abx2, X_abx2).fit(disp=False)
model_abx.summary()
# Out:
# Patient rows: 67343 Complete-case: 62727
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           group_binary   No. Observations:                62727
# Model:                          Logit   Df Residuals:                    62672
# Method:                           MLE   Df Model:                           54
# Date:                Sat, 14 Feb 2026   Pseudo R-squ.:                 0.01005
# Time:                        15:46:27   Log-Likelihood:                -37934.
# converged:                       True   LL-Null:                       -38319.
# Covariance Type:            nonrobust   LLR p-value:                2.659e-127
# ...
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# ...

# %%
X_pat_base = d_pat[baseline_cols_clean].copy()
for c in X_pat_base.columns:
    X_pat_base[c] = pd.to_numeric(X_pat_base[c], errors="coerce")

X_pat_base = sm.add_constant(X_pat_base, has_constant="add")
mask_pat_base = X_pat_base.notna().all(axis=1)

X_pat_base2 = X_pat_base.loc[mask_pat_base]
y_pat_base2 = d_pat.loc[mask_pat_base, "group_binary"].astype(int)

print("Patient baseline complete-case:", len(y_pat_base2))

model_baseline_pat = sm.Logit(y_pat_base2, X_pat_base2).fit(disp=False)
# Out:
# Patient baseline complete-case: 62727

# %%
from scipy.stats import chi2

lr_stat_abx = 2 * (model_abx.llf - model_baseline_pat.llf)
df_diff_abx = model_abx.df_model - model_baseline_pat.df_model
p_lr_abx = chi2.sf(lr_stat_abx, df_diff_abx)

lr_stat_abx, df_diff_abx, p_lr_abx
# Out:
# (np.float64(376.1157589848299), 15.0, np.float64(7.1359957855189615e-71))

# %%
params_abx = model_abx.params
conf_abx = model_abx.conf_int()

or_abx = pd.DataFrame({
    "OR": np.exp(params_abx),
    "CI_low": np.exp(conf_abx[0]),
    "CI_high": np.exp(conf_abx[1]),
    "p_value": model_abx.pvalues
})

or_abx_abxvars = (
    or_abx
    .loc[abx_cols]
    .sort_values("p_value")
)

or_abx_abxvars.head(10)
# Out:
#                                             OR    CI_low   CI_high  \
# any_abx_0_60                          0.523079  0.482251  0.567364
# extended_spectrum_penicillin_0_60     1.146318  1.060006  1.239658
# anti_anaerobe_0_60                    1.234826  1.067981  1.427737
# macrolide_0_60                        1.138318  1.015273  1.276275
# cephalosporin_0_60                    1.070538  1.005858  1.139377
# anti_Cdiff_0_60                       0.842822  0.662556  1.072134
# carbapenem_0_60                       1.111498  0.874721  1.412367
# glycopeptide_0_60                     0.919915  0.755762  1.119722
# extended_spectrum_cephalosporin_0_60  1.060859  0.915702  1.229027
# sulfonamide_0_60                      1.020757  0.951551  1.094997
#
#                                            p_value
# any_abx_0_60                          4.648347e-55
# extended_spectrum_penicillin_0_60     6.284263e-04
# anti_anaerobe_0_60                    4.399478e-03
# ...

# %%
# Build full design matrix (baseline + CP + ABX)
X_full = df[baseline_cols_clean + cp_cols + abx_cols].copy()

# force numeric
for c in X_full.columns:
    X_full[c] = pd.to_numeric(X_full[c], errors="coerce")

import statsmodels.api as sm
X_full = sm.add_constant(X_full, has_constant="add")
y_full = df["group_binary"].astype(int)

mask_full = X_full.notna().all(axis=1)

X_full2 = X_full.loc[mask_full]
y_full2 = y_full.loc[mask_full]

print("Full model rows:", len(y_full2))
# Out:
# Full model rows: 112808

# %%
model_full = sm.Logit(y_full2, X_full2).fit(disp=False)
model_full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           group_binary   No. Observations:               112808
# Model:                          Logit   Df Residuals:                   112744
# Method:                           MLE   Df Model:                           63
# Date:                Sat, 14 Feb 2026   Pseudo R-squ.:                 0.01010
# Time:                        15:47:02   Log-Likelihood:                -69763.
# converged:                       True   LL-Null:                       -70475.
# Covariance Type:            nonrobust   LLR p-value:                3.796e-256
# ...
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                   -0.6273      0.024    -25.784      0.000      -0.675      -0.580
# ...

# %%
from scipy.stats import chi2

lr_stat_full = 2 * (model_full.llf - model_cp.llf)
df_diff_full = model_full.df_model - model_cp.df_model
p_lr_full = chi2.sf(lr_stat_full, df_diff_full)

lr_stat_full, df_diff_full, p_lr_full
# Out:
# (np.float64(314.13646964667714), 15.0, np.float64(6.409233209608106e-58))

# %%
params_full = model_full.params
conf_full = model_full.conf_int()

or_full = pd.DataFrame({
    "OR": np.exp(params_full),
    "CI_low": np.exp(conf_full[0]),
    "CI_high": np.exp(conf_full[1]),
    "p_value": model_full.pvalues
}).sort_values("p_value")

or_full.loc[cp_cols + abx_cols].head(15)
# Out:
#                                             OR    CI_low   CI_high  \
# DS_Entero_cp                          0.988919  0.986678  0.991165
# ESBL_cp                               0.988238  0.982569  0.993941
# CDiff_cp                              0.980917  0.971455  0.990470
# VSE_cp                                1.000644  0.994820  1.006503
# VRE_cp                                1.021165  1.010836  1.031599
# MSSA_cp                               1.008525  1.002932  1.014150
# MRSA_cp                               0.990500  0.981804  0.999274
# DS_PsA_cp                             1.001204  0.992715  1.009766
# DR_PsA_cp                             1.001127  0.988967  1.013437
# any_abx_0_60                          0.612088  0.574239  0.652431
# penicillin_0_60                       1.026274  0.925141  1.138462
# extended_spectrum_penicillin_0_60     1.136419  1.061999  1.216055
# anti_staph_beta_lactam_0_60           1.070850  0.831379  1.379298
# ...
